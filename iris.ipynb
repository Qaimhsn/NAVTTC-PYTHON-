# %%
import pandas as pd
df=pd.read_csv("/home/jovyan/demo/iris.csv")
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2         se
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
a=df.drop(["species","sepal_width"],axis=1)
print(a)
# Out:
#      sepal_length  petal_length  petal_width
# 0             5.1           1.4          0.2
# 1             4.9           1.4          0.2
# 2             4.7           1.3          0.2
# 3             4.6           1.5          0.2
# 4             5.0           1.4          0.2
# 5             5.4           1.7          0.4
# 6             4.6           1.4          0.3
# 7             5.0           1.5          0.2
# 8             4.4           1.4          0.2
# 9             4.9           1.5          0.1
# 10            5.4           1.5          0.2
# 11            4.8           1.6          0.2
# 12            4.8           1.4          0.1
# 13            4.3           1.1          0.1
# 14            5.8           1.2          0.2
# 15            5.7           1.5          0.4
# 16            5.4           1.3          0.4
# 17            5.1           1.4          0.3
# 18            5.7           1.7          0.3
# 19            5.1           1.5          0.3
# ...

# %%
new_df=pd.read_csv("/home/jovyan/demo/annual-enterprise-survey-2019-financial-year-provisional-csv.csv")
print(new_df)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# 5      2019                     Level 1                99999
# 6      2019                     Level 1                99999
# 7      2019                     Level 1                99999
# 8      2019                     Level 1                99999
# 9      2019                     Level 1                99999
# 10     2019                     Level 1                99999
# 11     2019                     Level 1                99999
# 12     2019                     Level 1                99999
# 13     2019                     Level 1                99999
# ...

# %%
print(new_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32445 entries, 0 to 32444
# Data columns (total 10 columns):
# Year                           32445 non-null int64
# Industry_aggregation_NZSIOC    32445 non-null object
# Industry_code_NZSIOC           32445 non-null object
# Industry_name_NZSIOC           32445 non-null object
# Units                          32445 non-null object
# Variable_code                  32445 non-null object
# Variable_name                  32445 non-null object
# Variable_category              32445 non-null object
# Value                          32445 non-null object
# Industry_code_ANZSIC06         32445 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.5+ MB
# None

# %%
w=new_df.drop(["Industry_aggregation_NZSIOC","Industry_code_NZSIOC","Industry_name_NZSIOC"],axis=1)
print(w)
# Out:
#        Year               Units Variable_code  \
# 0      2019  Dollars (millions)           H01
# 1      2019  Dollars (millions)           H04
# 2      2019  Dollars (millions)           H05
# 3      2019  Dollars (millions)           H07
# 4      2019  Dollars (millions)           H08
# 5      2019  Dollars (millions)           H09
# 6      2019  Dollars (millions)           H10
# 7      2019  Dollars (millions)           H11
# 8      2019  Dollars (millions)           H12
# 9      2019  Dollars (millions)           H13
# 10     2019  Dollars (millions)           H14
# 11     2019  Dollars (millions)           H19
# 12     2019  Dollars (millions)           H20
# 13     2019  Dollars (millions)           H21
# 14     2019  Dollars (millions)           H22
# 15     2019  Dollars (millions)           H23
# 16     2019  Dollars (millions)           H24
# 17     2019  Dollars (millions)           H25
# 18     2019  Dollars (millions)           H26
# ...
