# %%
import pandas as pd

# %%
data_set=pd.read_csv("/home/jovyan/demo/data/iris.csv")
print(data_set)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2         se
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
data_set.loc[data_set['petal_length'] > 4.5] = 5   
data_set["petal_length"]
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
# 5      1.7
# 6      1.4
# 7      1.5
# 8      1.4
# 9      1.5
# 10     1.5
# 11     1.6
# 12     1.4
# 13     1.1
# 14     1.2
# 15     1.5
# 16     1.3
# 17     1.4
# 18     1.7
# 19     1.5
# 20     1.7
# 21     1.5
# 22     1.0
# 23     1.7
# 24     1.9
# 25     1.6
# 26     1.6
# 27     1.5
# 28     1.4
# 29     1.6
#       ...
# 120    5.0
# 121    5.0
# 122    5.0
# 123    5.0
# 124    5.0
# 125    5.0
# 126    5.0
# 127    5.0
# 128    5.0
# 129    5.0
# 130    5.0
# 131    5.0
# 132    5.0
# 133    5.0
# 134    5.0
# 135    5.0
# 136    5.0
# 137    5.0
# 138    5.0
# 139    5.0
# 140    5.0
# 141    5.0
# 142    5.0
# 143    5.0
# 144    5.0
# 145    5.0
# 146    5.0
# 147    5.0
# 148    5.0
# 149    5.0
# Name: petal_length, Length: 150, dtype: float64
