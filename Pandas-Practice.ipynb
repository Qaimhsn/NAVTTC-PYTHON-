# %%
import pandas as pd

# %%
dataset={'car':["hyundai","Accord","suzuki","Landcruiser"],
        'win':[1,2,3,4]}
report=pd.DataFrame(dataset,index=[1,2,3,4])
print(report)
print(report.loc[1])
# Out:
#            car  win
# 1      hyundai    1
# 2       Accord    2
# 3       suzuki    3
# 4  Landcruiser    4
# car    hyundai
# win          1
# Name: 1, dtype: object

# %%
dataset={'Subject':["Mathematic","Physics","Chemistry","Biology"],
        'Marks':[60,80,90,70]}
report=pd.DataFrame(dataset)
print(report)
# Out:
#       Subject  Marks
# 0  Mathematic     60
# 1     Physics     80
# 2   Chemistry     90
# 3     Biology     70

# %%
a=[1,2,3,4,5]
pd_set=pd.Series(a)
print(pd_set)
print(pd_set[1])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# 2

# %%
calories={'day0':40,'day1':50,'day2':70,'day3':60,'day4':90}
report_3=pd.Series(calories)
print(report_3)
print(report_3[1])
# Out:
# day0    40
# day1    50
# day2    70
# day3    60
# day4    90
# dtype: int64
# 50

# %%
dataset_5={
    'name':["arsal","ali","hamza","umar","kumail","osama","adil","huzaifa","hasan","nabeel"],
    'math':[60,69,56,22,66,88,87,65,91,59],
    'phy': [60,69,56,22,66,88,87,65,91,59],
    'chem':[60,69,56,22,66,88,87,65,91,59],
    'bio':[60,69,56,22,66,88,87,65,91,59]
}
report_4 = pd.DataFrame(dataset_5)
print(report_4)
# Out:
#       name  math  phy  chem  bio
# 0    arsal    60   60    60   60
# 1      ali    69   69    69   69
# 2    hamza    56   56    56   56
# 3     umar    22   22    22   22
# 4   kumail    66   66    66   66
# 5    osama    88   88    88   88
# 6     adil    87   87    87   87
# 7  huzaifa    65   65    65   65
# 8    hasan    91   91    91   91
# 9   nabeel    59   59    59   59

# %%
df=pd.read_csv(r"C:\Users\student\Desktop\try.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-61333298b089> in <module>
# ----> 1 df=pd.read_csv(r"C:\Users\student\Desktop\try.csv")
#       2 print(df)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...
